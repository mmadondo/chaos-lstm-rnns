# %% [markdown]
# ## Learning and Predicting Chaos Using LSTM RNNs

# %%
from ipywidgets import interact, interactive
from IPython.display import clear_output, display, HTML

# %%
import numpy as np
from scipy import integrate
from matplotlib import pyplot as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import cnames
from matplotlib import animation

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Lambda, Flatten, LSTM, SimpleRNN
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import Adam, RMSprop
from keras.utils import np_utils
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ## Generate Time Series using the Lorenz System of DE

# %%
def solve_lorenz_graph(N=10, angle=0.0, max_time=4.0, sigma=10.0, beta=8.0/3, rho=28.0):

    fig = plt.figure()
    ax = fig.add_axes([0, 0, 1, 1], projection='3d')
    ax.axis('on')
    SEQUENCE_SIZE = 100         # length of the sequence to generate
    # prepare the axes limits
    ax.set_xlim((-25, 25))
    ax.set_ylim((-35, 35))
    ax.set_zlim((5, 55))
    
    # Label the axes
    ax.set_title('The Lorenz Attractor')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')

    def lorenz_deriv(x_y_z, t0, sigma=sigma, beta=beta, rho=rho):
        """Compute the time-derivative of a Lorenz system."""
        x, y, z = x_y_z
        return [sigma * (y - x), x * (rho - z) - y, x * y - beta * z]

    # Choose random starting points, uniformly distributed from -15 to 15
    np.random.seed(1)
    x0 = -15 + 30 * np.random.random((N, 3))

    # Solve for the trajectories
    t = np.linspace(0, max_time, int(250*max_time))
    x_t = np.asarray([integrate.odeint(lorenz_deriv, x0i, t)
                      for x0i in x0])

    # choose a different color for each trajectory
    colors = plt.cm.viridis(np.linspace(0, 1, N))

    for i in range(N):
        x, y, z = x_t[i,:,:].T
       # print(x, y, z) #print the data
        lines = ax.plot(x, y, z, '-', c=colors[i])
        plt.setp(lines, linewidth=2)

    ax.view_init(30, angle)
    plt.show()

    return t, x_t

# %%
def solve_lorenz(N=10, max_time=4.0, sigma=10.0, beta=8.0/3, rho=28.0):
    
    #define ODE function we need to solve
    def lorenz_deriv(x_y_z, t0, sigma=sigma, beta=beta, rho=rho):
        """Compute the time-derivative of a Lorenz system."""
        x, y, z = x_y_z
        return [sigma * (y - x), x * (rho - z) - y, x * y - beta * z]

    # Choose N random starting points, uniformly distributed from -15 to 15
    np.random.seed(1)
    x0 = -15 + 30 * np.random.random((N, 3))

    # Solve for the trajectories
    # First generate a list of time steps starting at zero and going to max_time. 250 steps for each time unit
    t = np.linspace(0, max_time, int(250*max_time))
    # Second integrate the ODE using the lorenz_deriv funtion above for each random starting point
    x_t = np.asarray([integrate.odeint(lorenz_deriv, x0i, t)
                      for x0i in x0])

    return t, x_t

# %%
sigma=10.0
beta=8.0/3
rho=28.0
def lorenz_deriv(x_y_z, t0, sigma=sigma, beta=beta, rho=rho):
    """Compute the time-derivative of a Lorenz system."""
    x, y, z = x_y_z
    return [sigma * (y - x), x * (rho - z) - y, x * y - beta * z]

# %%
#print (t)

# %%
N=5
max_time = 4.0
#original code generated an array of starting points
x0 = -15 + 30 * np.random.random((N, 3))
print (x0)
# generate one random starting point at a time
point1 = np.random.random(3)
print ("Random point1 = ",point1)

sigma = 10.0
beta = 8.0/3
rho = 28.0

# Solve for the trajectories
# First generate a list of time steps starting a zero and going to max_time. 250 steps for each time unit
t = np.linspace(0, max_time, int(250*max_time))
print ("shape of t = ", t.shape)
#print (" t = " , t)

# Second integrate the ODE using the lorenz_deriv funtion above
#lor1 = integrate.odeint(lorenz_deriv, point1, t, sigma, beta, rho)
lor1 = integrate.odeint(lorenz_deriv, point1, t)
print (" lor1 = ", lor1)
print ("shape of lor1 = ", lor1.shape)

# Do it with a different random starting point-- integrate the ODE using the lorenz_deriv funtion above
point2 = -15 + 30 * np.random.random(3)
lor2 = integrate.odeint(lorenz_deriv, point2, t)

# Do it with a different random starting point-- integrate the ODE using the lorenz_deriv funtion above
point3 = -15 + 30 * np.random.random(3)
lor3 = integrate.odeint(lorenz_deriv, point3, t)

#x_t = np.asarray([integrate.odeint(lorenz_deriv, x0i, t)
#                   for x0i in x0])
# Out:
# [[  2.117923     7.21432426   6.74720479]
#  [  4.4032229    1.09271154  13.80011149]
#  [-11.53914672 -13.71035595   1.81734672]
#  [-12.19932506  14.68043626  -5.55802106]
#  [ 14.34171996  11.86381469 -12.39602783]]
# Random point1 =  [0.12289011 0.51406552 0.31300943]
# shape of t =  (1000,)
#  lor1 =  [[  0.12289011   0.51406552   0.31300943]
#  [  0.13848297   0.52647268   0.30995594]
#  [  0.15398388   0.54055152   0.3069748 ]
#  ...
#  [ -8.65162262 -10.08017131  25.21379109]
#  [ -8.70878537 -10.13512495  25.29544733]
#  [ -8.76581246 -10.1875765   25.38040416]]
# shape of lor1 =  (1000, 3)

# %%
# from matplotlib import pyplot as plt
# %matplotlib inline
plt.plot(lor1)
plt.plot(lor2)
plt.plot(lor3)
# Out:
# [<matplotlib.lines.Line2D at 0x11cc65438>,
#  <matplotlib.lines.Line2D at 0x11cc655c0>,
#  <matplotlib.lines.Line2D at 0x11cc65710>]

# %%
plt.subplot(3 ,1, 1)
plt.title("X ")
plt.plot(lor1[:,0:1] )
plt.plot(lor2[:,0:1] )
plt.plot(lor3[:,0:1] )
#plt.show()

plt.subplot(3, 1, 2)
plt.title("Y ")
plt.plot(lor1[:,1:2] )
plt.plot(lor2[:,1:2] )
plt.plot(lor3[:,1:2] )
#plt.show()

plt.subplot(3, 1, 3)
plt.title("Z ")
plt.plot(lor1[:,2:3] )
plt.plot(lor2[:,2:3] )
plt.plot(lor3[:,2:3] )
plt.tight_layout() #add spacing between subplots
plt.show()

# %%
t, x_t = solve_lorenz_graph(angle=134, N=10) #angle initially at 0, butterfly at 134

# %%
widget = interactive(solve_lorenz_graph, angle=(0.,360.), max_time=(0.1, 10.0),
                N=(0,50), sigma=(0.0,50.0), rho=(0.0,50.0))
display(widget)
# Out:
# A Jupyter Widget

# %%
#t, x_t = widget.result

# %%
t, x_t = solve_lorenz(N=10) #try 10 random starting point initially, change to 100 later

# %%
print ("lorenz output shape : " , x_t.shape)
# Out:
# lorenz output shape :  (10, 1000, 3)

# %%
print ("lorenz output : " , x_t)
# Out:
# lorenz output :  [[[-2.48933986e+00  6.60973480e+00 -1.49965688e+01]
#   [-2.14077645e+00  6.18646806e+00 -1.48962127e+01]
#   [-1.82130748e+00  5.82299967e+00 -1.47853208e+01]
#   ...
#   [ 6.87667416e+00  1.07734499e+01  1.78286316e+01]
#   [ 7.03431517e+00  1.10115546e+01  1.79410297e+01]
#   [ 7.19515729e+00  1.12517722e+01  1.80659207e+01]]
#
#  [[-5.93002282e+00 -1.05973233e+01 -1.22298422e+01]
#   [-6.13136261e+00 -1.15193465e+01 -1.18344052e+01]
#   [-6.36138540e+00 -1.24619735e+01 -1.14104771e+01]
#   ...
#   [-1.11085203e+01 -1.62261151e+01  2.32341935e+01]
#   [-1.13121656e+01 -1.63640151e+01  2.37150767e+01]
#   [-1.15128567e+01 -1.64827701e+01  2.42098140e+01]]
#
#  [[-9.41219366e+00 -4.63317819e+00 -3.09697577e+00]
#   [-9.24717733e+00 -5.76936651e+00 -2.87083263e+00]
#   [-9.13260659e+00 -6.87477643e+00 -2.60897637e+00]
#   ...
#   [ 8.94933599e+00  1.00204877e+01  2.61339939e+01]
#   [ 8.99188828e+00  1.00458891e+01  2.62149083e+01]
#   [ 9.03371359e+00  1.00685518e+01  2.62975123e+01]]
#
#  ...
#
#  [[ 1.40478473e+01 -5.59727466e+00  5.76967847e+00]
#   [ 1.33015844e+01 -4.35137818e+00  5.43762841e+00]
#   [ 1.26324566e+01 -3.15868945e+00  5.18607122e+00]
#   ...
#   [-5.62183444e+00 -9.08227752e+00  1.57576353e+01]
#   [-5.76241216e+00 -9.32397964e+00  1.57989149e+01]
#   [-5.90705639e+00 -9.57059699e+00  1.58506576e+01]]
#
#  [[ 1.12916746e+01  1.18381999e+01 -1.24486737e+01]
#   [ 1.13481065e+01  1.36039497e+01 -1.17430178e+01]
#   [ 1.14710812e+01  1.53431579e+01 -1.09606825e+01]
#   ...
#   [-1.47676704e-02 -1.23192227e-02  1.01977111e+01]
#   [-1.46913669e-02 -1.33207565e-02  1.00894067e+01]
#   [-1.46573258e-02 -1.43206799e-02  9.98225248e+00]]
#
#  [[-1.38283565e+01 -9.90508741e+00  1.13442751e+01]
#   [-1.36915606e+01 -1.07690154e+01  1.17903119e+01]
#   [-1.35933180e+01 -1.15964765e+01  1.22727276e+01]
#   ...
#   [ 1.61306741e+01  1.93584734e+01  3.43088188e+01]
#   [ 1.62473985e+01  1.88446346e+01  3.51764615e+01]
#   [ 1.63382575e+01  1.82747191e+01  3.60076113e+01]]]

# %% [markdown]
# ## Convert data into format for Keras

# %%
# split into train and test sets
train_size = int(len(x_t)* 0.70)
print(train_size)
test_size = len(x_t) - train_size
lorenz_train = x_t[0:train_size]
lorenz_test  = x_t[train_size:len(x_t)]
print ("train shape : " , lorenz_train.shape)
print ("test shape : " , lorenz_test.shape)
# Out:
# 7
# train shape :  (7, 1000, 3)
# test shape :  (3, 1000, 3)

# %%
def to_sequences(seq_size, obs): 
    x = []
    y = []
    for i in range(len(obs)-SEQUENCE_SIZE-1):
        #print(i)
        window = obs[i:(i+SEQUENCE_SIZE)]
        after_window = obs[i+SEQUENCE_SIZE]
        window = [x for x in window]
        #print("{} - {}".format(window,after_window))
        x.append(window)
        y.append(after_window)
    return np.array(x),np.array(y)

# %%
def to_sequences_ray(seq_size, obs): 
    #x = []
    #y = []
    x, y = to_sequences(SEQUENCE_SIZE,obs[0])
    for i in range(len(obs)):
        xtemp, ytemp = to_sequences(SEQUENCE_SIZE,obs[i])
        x = np.concatenate((x, xtemp), axis=0)
        y = np.concatenate((y, ytemp), axis=0)
        #x.append(xtemp)
        #y.append(ytemp)
    return np.array(x),np.array(y)

# %%
data_segment = lorenz_train[1]
print("training data segment shape ", lorenz_train[0].shape)
print("training data segment ", lorenz_train[1])
# Out:
# training data segment shape  (1000, 3)
# training data segment  [[ -5.93002282 -10.59732328 -12.22984216]
#  [ -6.13136261 -11.51934646 -11.83440517]
#  [ -6.3613854  -12.4619735  -11.41047706]
#  ...
#  [-11.10852032 -16.22611514  23.23419346]
#  [-11.31216558 -16.36401507  23.71507674]
#  [-11.51285672 -16.48277012  24.20981403]]

# %%
#train = np.apply_along_axis(to_sequences_ray, 1, lorenz_train)
print (lorenz_train.shape)
print (lorenz_test.shape)
print (len(lorenz_train))
# Out:
# (7, 1000, 3)
# (3, 1000, 3)
# 7

# %%
# reshape input to be [samples, time steps, features]
'''
trainX = np.reshape(lorenz_train, (lorenz_train.shape[0], 1, lorenz_train.shape[1]))
testX = np.reshape(lorenz_test, (lorenz_test.shape[0], 1, lorenz_test.shape[1]))
print(trainX.shape)
print(testX.shape)
'''
# Out:
# '\ntrainX = np.reshape(lorenz_train, (lorenz_train.shape[0], 1, lorenz_train.shape[1]))\ntestX = np.reshape(lorenz_test, (lorenz_test.shape[0], 1, lorenz_test.shape[1]))\nprint(trainX.shape)\nprint(testX.shape)\n'

# %%
SEQUENCE_SIZE = 10
x_train,y_train = to_sequences_ray(SEQUENCE_SIZE,lorenz_train)
#print(lorenz_train)
x_test,y_test = to_sequences_ray(SEQUENCE_SIZE,lorenz_test)
print("Shape of training input: ", x_train.shape)
print ("Shape of training output: " , y_train.shape)
print("Shape of test input: ", x_test.shape)
print ("Shape of testing output: " , y_test.shape)
# Out:
# Shape of training input:  (7912, 10, 3)
# Shape of training output:  (7912, 3)
# Shape of test input:  (3956, 10, 3)
# Shape of testing output:  (3956, 3)

# %%
print (x_train[1])
# Out:
# [[ -2.14077645   6.18646806 -14.8962127 ]
#  [ -1.82130748   5.82299967 -14.78532082]
#  [ -1.52754738   5.5141974  -14.66604305]
#  [ -1.25643353   5.25549013 -14.5400914 ]
#  [ -1.00519263   5.04282303 -14.40882193]
#  [ -0.77130991   4.87261417 -14.27330094]
#  [ -0.55250119   4.74171357 -14.1343581 ]
#  [ -0.3466877    4.64736514 -13.99262854]
#  [ -0.15197325   4.58717161 -13.84858652]
#  [  0.03337642   4.55906245 -13.70257219]]

# %%
print (y_train[1])
# Out:
# [  0.21095219   4.56126473 -13.55481228]

# %%
print (x_test[1])
# Out:
# [[13.30158439 -4.35137818  5.43762841]
#  [12.63245662 -3.15868945  5.18607122]
#  [12.03537919 -2.01748237  5.00395449]
#  [11.50555101 -0.92525235  4.88190821]
#  [11.03846858  0.12101607  4.81206154]
#  [10.62993013  1.12464381  4.78786651]
#  [10.27603255  2.08910202  4.80393473]
#  [ 9.97316317  3.01789585  4.85588914]
#  [ 9.71798789  3.91447848  4.94023197]
#  [ 9.50743691  4.78218811  5.05422845]]

# %%
print (y_test[1])
# Out:
# [9.33868889 5.62420225 5.19580543]

# %% [markdown]
# ## Build Neural Network model in Keras

# %%
print('Build LSTM model...')
model = Sequential()
model.add(LSTM(16, input_shape=(None, 3)))
model.add(Dense(3))
model.compile(loss='mean_squared_error', optimizer='adam')

#monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, verbose=1, mode='auto')
print('Train...')
# Out:
# Build LSTM model...
# Train...

# %%
print('Build RNN model...')
RNNmodel = Sequential()
RNNmodel.add(SimpleRNN(16, input_shape=(None, 3)))
RNNmodel.add(Dense(3))
RNNmodel.compile(loss='mean_squared_error', optimizer='adam')
print('Train RNN...')
# Out:
# Build RNN model...
# Train RNN...

# %%
print('Train LSTM model...')
model.fit(x_train,y_train,validation_data=(x_test,y_test),verbose=2,epochs=50)
# Out:
# Train LSTM model...
# Train on 7912 samples, validate on 3956 samples
# Epoch 1/50
#  - 5s - loss: 246.9789 - val_loss: 175.7338
# Epoch 2/50
#  - 4s - loss: 155.1471 - val_loss: 119.7063
# Epoch 3/50
#  - 5s - loss: 110.8659 - val_loss: 89.1309
# Epoch 4/50
#  - 5s - loss: 82.5815 - val_loss: 61.9859
# Epoch 5/50
#  - 6s - loss: 57.3085 - val_loss: 45.9321
# Epoch 6/50
#  - 5s - loss: 43.1207 - val_loss: 35.1308
# Epoch 7/50
#  - 4s - loss: 33.2688 - val_loss: 27.4253
# Epoch 8/50
#  - 4s - loss: 26.2312 - val_loss: 21.8865
# Epoch 9/50
#  - 4s - loss: 21.1975 - val_loss: 17.6623
# Epoch 10/50
#  - 6s - loss: 17.5081 - val_loss: 14.4470
# Epoch 11/50
#  - 5s - loss: 14.7244 - val_loss: 11.9865
# Epoch 12/50
#  - 4s - loss: 12.5769 - val_loss: 10.0512
# Epoch 13/50
#  - 4s - loss: 10.8228 - val_loss: 8.4242
# Epoch 14/50
#  - 4s - loss: 9.3555 - val_loss: 7.1094
# Epoch 15/50
#  - 4s - loss: 8.1314 - val_loss: 6.0812
# Epoch 16/50
#  - 4s - loss: 7.1013 - val_loss: 5.2005
# Epoch 17/50
#  - 4s - loss: 6.2141 - val_loss: 4.5151
# Epoch 18/50
#  - 4s - loss: 5.4591 - val_loss: 3.8302
# Epoch 19/50
#  - 4s - loss: 4.8134 - val_loss: 3.3665
# Epoch 20/50
#  - 4s - loss: 4.2509 - val_loss: 2.9182
# Epoch 21/50
#  - 4s - loss: 3.7664 - val_loss: 2.5927
# Epoch 22/50
#  - 4s - loss: 3.3427 - val_loss: 2.2689
# Epoch 23/50
#  - 4s - loss: 2.9698 - val_loss: 2.0298
# Epoch 24/50
#  - 4s - loss: 2.6442 - val_loss: 1.8350
# Epoch 25/50
#  - 5s - loss: 2.3660 - val_loss: 1.6249
# Epoch 26/50
#  - 4s - loss: 2.1080 - val_loss: 1.4698
# Epoch 27/50
#  - 4s - loss: 1.8879 - val_loss: 1.3195
# Epoch 28/50
#  - 5s - loss: 1.6930 - val_loss: 1.2037
# Epoch 29/50
#  - 4s - loss: 1.5244 - val_loss: 1.1878
# Epoch 30/50
#  - 4s - loss: 1.3678 - val_loss: 0.9779
# Epoch 31/50
#  - 4s - loss: 1.2062 - val_loss: 0.8930
# Epoch 32/50
#  - 4s - loss: 1.0632 - val_loss: 0.7963
# Epoch 33/50
#  - 4s - loss: 0.9510 - val_loss: 0.7404
# Epoch 34/50
#  - 4s - loss: 0.8428 - val_loss: 0.6642
# Epoch 35/50
#  - 4s - loss: 0.7363 - val_loss: 0.6090
# Epoch 36/50
#  - 4s - loss: 0.6450 - val_loss: 0.5500
# Epoch 37/50
#  - 4s - loss: 0.5863 - val_loss: 0.5169
# Epoch 38/50
#  - 4s - loss: 0.4891 - val_loss: 0.4568
# Epoch 39/50
#  - 4s - loss: 0.4211 - val_loss: 0.4209
# Epoch 40/50
#  - 4s - loss: 0.3660 - val_loss: 0.3753
# Epoch 41/50
#  - 4s - loss: 0.3139 - val_loss: 0.3284
# Epoch 42/50
#  - 4s - loss: 0.2713 - val_loss: 0.2966
# Epoch 43/50
#  - 4s - loss: 0.2327 - val_loss: 0.2770
# Epoch 44/50
#  - 4s - loss: 0.2050 - val_loss: 0.2600
# Epoch 45/50
#  - 4s - loss: 0.1778 - val_loss: 0.2152
# Epoch 46/50
#  - 4s - loss: 0.1511 - val_loss: 0.1867
# Epoch 47/50
#  - 4s - loss: 0.1202 - val_loss: 0.1825
# Epoch 48/50
#  - 4s - loss: 0.1046 - val_loss: 0.1474
# Epoch 49/50
#  - 4s - loss: 0.0904 - val_loss: 0.1366
# Epoch 50/50
#  - 4s - loss: 0.0841 - val_loss: 0.1294

# %%
print('Train RNN model...')
RNNmodel.fit(x_train,y_train,validation_data=(x_test,y_test),verbose=2,epochs=50)
# Out:
# Train RNN model...
# Train on 7912 samples, validate on 3956 samples
# Epoch 1/50
#  - 2s - loss: 229.4236 - val_loss: 188.2107
# Epoch 2/50
#  - 2s - loss: 171.7267 - val_loss: 138.4173
# Epoch 3/50
#  - 2s - loss: 125.6863 - val_loss: 102.8861
# Epoch 4/50
#  - 1s - loss: 94.2434 - val_loss: 77.4204
# Epoch 5/50
#  - 1s - loss: 71.7584 - val_loss: 59.3949
# Epoch 6/50
#  - 1s - loss: 55.3805 - val_loss: 46.2221
# Epoch 7/50
#  - 1s - loss: 43.2076 - val_loss: 36.1415
# Epoch 8/50
#  - 1s - loss: 33.9788 - val_loss: 28.6176
# Epoch 9/50
#  - 1s - loss: 27.2303 - val_loss: 23.0668
# Epoch 10/50
#  - 1s - loss: 22.2451 - val_loss: 18.8225
# Epoch 11/50
#  - 1s - loss: 18.5137 - val_loss: 15.5161
# Epoch 12/50
#  - 1s - loss: 15.7066 - val_loss: 12.9305
# Epoch 13/50
#  - 1s - loss: 13.4801 - val_loss: 10.8653
# Epoch 14/50
#  - 1s - loss: 11.6808 - val_loss: 9.1999
# Epoch 15/50
#  - 2s - loss: 10.2018 - val_loss: 7.8720
# Epoch 16/50
#  - 1s - loss: 8.9583 - val_loss: 6.7838
# Epoch 17/50
#  - 1s - loss: 7.8870 - val_loss: 5.8314
# Epoch 18/50
#  - 1s - loss: 6.9703 - val_loss: 5.0938
# Epoch 19/50
#  - 1s - loss: 6.1750 - val_loss: 4.4550
# Epoch 20/50
#  - 1s - loss: 5.4813 - val_loss: 3.9036
# Epoch 21/50
#  - 1s - loss: 4.8843 - val_loss: 3.4361
# Epoch 22/50
#  - 1s - loss: 4.3430 - val_loss: 3.0207
# Epoch 23/50
#  - 1s - loss: 3.8664 - val_loss: 2.6694
# Epoch 24/50
#  - 1s - loss: 3.4482 - val_loss: 2.3776
# Epoch 25/50
#  - 1s - loss: 3.0765 - val_loss: 2.1192
# Epoch 26/50
#  - 1s - loss: 2.7511 - val_loss: 1.9049
# Epoch 27/50
#  - 1s - loss: 2.4697 - val_loss: 1.7254
# Epoch 28/50
#  - 2s - loss: 2.2139 - val_loss: 1.5689
# Epoch 29/50
#  - 2s - loss: 1.9841 - val_loss: 1.4122
# Epoch 30/50
#  - 2s - loss: 1.7806 - val_loss: 1.2991
# Epoch 31/50
#  - 1s - loss: 1.5934 - val_loss: 1.1697
# Epoch 32/50
#  - 2s - loss: 1.4231 - val_loss: 1.0945
# Epoch 33/50
#  - 1s - loss: 1.2702 - val_loss: 0.9836
# Epoch 34/50
#  - 1s - loss: 1.1238 - val_loss: 0.9047
# Epoch 35/50
#  - 1s - loss: 1.0191 - val_loss: 0.8082
# Epoch 36/50
#  - 1s - loss: 0.8857 - val_loss: 0.7420
# Epoch 37/50
#  - 1s - loss: 0.7896 - val_loss: 0.6803
# Epoch 38/50
#  - 1s - loss: 0.6884 - val_loss: 0.6264
# Epoch 39/50
#  - 1s - loss: 0.5982 - val_loss: 0.5670
# Epoch 40/50
#  - 1s - loss: 0.5254 - val_loss: 0.5056
# Epoch 41/50
#  - 1s - loss: 0.4482 - val_loss: 0.4685
# Epoch 42/50
#  - 1s - loss: 0.3895 - val_loss: 0.4141
# Epoch 43/50
#  - 2s - loss: 0.3452 - val_loss: 0.3833
# Epoch 44/50
#  - 2s - loss: 0.2933 - val_loss: 0.3302
# Epoch 45/50
#  - 1s - loss: 0.2547 - val_loss: 0.2989
# Epoch 46/50
#  - 2s - loss: 0.2187 - val_loss: 0.2750
# Epoch 47/50
#  - 2s - loss: 0.1854 - val_loss: 0.2502
# Epoch 48/50
#  - 2s - loss: 0.1596 - val_loss: 0.2174
# Epoch 49/50
#  - 2s - loss: 0.1392 - val_loss: 0.2082
# Epoch 50/50
#  - 1s - loss: 0.1218 - val_loss: 0.1863

# %% [markdown]
# ## Plot original values and predictions

# %%
trainPredict = model.predict(x_train)
testPredict = model.predict(x_test)
RNNtrainPredict = RNNmodel.predict(x_train)
RNNtestPredict = RNNmodel.predict(x_test)

# %%
from matplotlib import pyplot as plt
# plot baseline and predictions
print("Graphing LSTM and RNN on Training data ")
plt.figure(figsize=(20,20))
plt.subplot(2 ,1, 1)
plt.title("LSTM Model ")
plt.plot(y_train, linestyle='-', label='Original')
plt.plot(trainPredict, linestyle=':', label='Prediction - LSTM')
plt.legend(loc='upper right', shadow=True)

plt.subplot(2, 1, 2)
plt.title("RNN Model ")
plt.plot(y_train, linestyle='-', label='Original')
plt.plot(RNNtrainPredict, linestyle=':', label='Prediction - RNN')
plt.legend(loc='upper right', shadow=True)
plt.show()
# Out:
# Graphing LSTM and RNN on Training data

# %%
list = np.arange(len(trainPredict)+10,len(trainPredict)+len(testPredict)+10)
plt.plot(list, testPredict) # plot baseline and predictions
# Out:
# [<matplotlib.lines.Line2D at 0x11fb0fda0>,
#  <matplotlib.lines.Line2D at 0x11fb0fef0>,
#  <matplotlib.lines.Line2D at 0x11fb17080>]

# %%
print(trainPredict-y_train)
# Out:
# [[ 0.15283256  0.03237537  0.08087476]
#  [ 0.14489079  0.04123571  0.04757294]
#  [ 0.14022094  0.0377304   0.02527984]
#  ...
#  [ 0.0019806  -0.17914951 -0.04456082]
#  [-0.00037662 -0.17913654 -0.04901496]
#  [-0.00098583 -0.17797282 -0.05351063]]

# %% [markdown]
# ## Calculate difference between prediction and actual

# %%
print("Graphing LSTM true test output against predicted output ")
plt.figure(figsize=(20,10))
plt.title("X for LSTM testing data vs results ")
plt.plot(y_test[:,0:1], linewidth=1.0, label='Actual X')
plt.plot(testPredict[:,0:1], linestyle=':', label='Predicted X')
plt.legend(loc='upper right', shadow=True)
plt.show()
# Out:
# Graphing LSTM true test output against predicted output

# %%
print("Graphing RNN true test output against predicted output ")
plt.figure(figsize=(20,10))
plt.title("X for RNN testing data vs results ")
plt.plot(y_test[:,0:1], linewidth=1.0, label='Actual X')
plt.plot(RNNtestPredict[:,0:1], linestyle=':', label='Predicted X')
plt.legend(loc='upper right', shadow=True)
plt.show()
# Out:
# Graphing RNN true test output against predicted output

# %%
print("Graphing LSTM true test output against predicted output ")
plt.figure(figsize=(20,20))
plt.subplot(3 ,1, 1)
plt.title("X for LSTM testing data vs results")
plt.plot(y_test[:,0:1], linewidth=1.0, label='Actual X')
plt.plot(testPredict[:,0:1], linestyle=':', label='Predicted X')
plt.legend(loc='upper right', shadow=True)

plt.subplot(3, 1, 2)
plt.title("Y for LSTM testing data vs results")
plt.plot(y_test[:,1:2], linewidth=1.0, label='Actual Y')
plt.plot(testPredict[:,1:2], linestyle=':', label='Predicted Y')
plt.legend(loc='upper right', shadow=True)

plt.subplot(3, 1, 3)
plt.title("Z for LSTM testing data vs results")
plt.plot(y_test[:,2:3], linewidth=1.0, label='Actual Z')
plt.plot(testPredict[:,2:3], linestyle=':', label='Predicted Z')
plt.legend(loc='upper right', shadow=True)
plt.show()
# Out:
# Graphing LSTM true test output against predicted output

# %%
print("Graphing RNN true test output against predicted output ")
plt.figure(figsize=(20,20))
plt.subplot(3 ,1, 1)
plt.title("X for RNN testing data vs results")
plt.plot(y_test[:,0:1], linewidth=1.0, label='Actual X')
plt.plot(testPredict[:,0:1], linestyle=':', label='Predicted X')
plt.legend(loc='upper right', shadow=True)

plt.subplot(3, 1, 2)
plt.title("Y for RNN testing data vs results")
plt.plot(y_test[:,1:2], linewidth=1.0, label='Actual Y')
plt.plot(testPredict[:,1:2], linestyle=':', label='Predicted Y')
plt.legend(loc='upper right', shadow=True)

plt.subplot(3, 1, 3)
plt.title("Z for RNN testing data vs results")
plt.plot(y_test[:,2:3], linewidth=1.0, label='Actual Z')
plt.plot(testPredict[:,2:3], linestyle=':', label='Predicted Z')
plt.legend(loc='upper right', shadow=True)
plt.show()
# Out:
# Graphing RNN true test output against predicted output

# %%
print (y_test.shape)
print (y_test)
# Out:
# (3956, 3)
# [[ 9.50743691  4.78218811  5.05422845]
#  [ 9.33868889  5.62420225  5.19580543]
#  [ 9.20915422  6.44350491  5.36346359]
#  ...
#  [15.98936717 19.81395459 33.41044267]
#  [16.1306741  19.35847338 34.30881879]
#  [16.2473985  18.84463462 35.17646154]]

# %%
y_test_win = [[x] for x in y_test]
y_test_win = np.array(y_test_win)
print (y_test_win.shape)
print (y_test_win)
# Out:
# (3956, 1, 3)
# [[[ 9.50743691  4.78218811  5.05422845]]
#
#  [[ 9.33868889  5.62420225  5.19580543]]
#
#  [[ 9.20915422  6.44350491  5.36346359]]
#
#  ...
#
#  [[15.98936717 19.81395459 33.41044267]]
#
#  [[16.1306741  19.35847338 34.30881879]]
#
#  [[16.2473985  18.84463462 35.17646154]]]

# %%
print (testPredict.shape)
print (testPredict)
# Out:
# (3956, 3)
# [[12.006091   4.066236   3.4326484]
#  [11.480213   5.2961     3.7163732]
#  [10.619234   6.5526414  4.481695 ]
#  ...
#  [16.268673  19.980272  33.227867 ]
#  [16.402134  19.526161  34.160095 ]
#  [16.504335  19.003561  35.072166 ]]

# %%
test_diff = testPredict-y_test_win
print(testPredict-y_test_win)
# Out:
# [[[ 2.49865421e+00 -7.15952091e-01 -1.62158003e+00]
#   [ 1.97277626e+00  5.13912030e-01 -1.33785525e+00]
#   [ 1.11179718e+00  1.77045328e+00 -5.72533280e-01]
#   ...
#   [ 6.76123604e+00  1.51980842e+01  2.81736387e+01]
#   [ 6.89469703e+00  1.47439731e+01  2.91058668e+01]
#   [ 6.99689850e+00  1.42213729e+01  3.00179380e+01]]
#
#  [[ 2.66740223e+00 -1.55796623e+00 -1.76315701e+00]
#   [ 2.14152427e+00 -3.28102106e-01 -1.47943222e+00]
#   [ 1.28054519e+00  9.28439146e-01 -7.14110251e-01]
#   ...
#   [ 6.92998405e+00  1.43560700e+01  2.80320617e+01]
#   [ 7.06344505e+00  1.39019589e+01  2.89642898e+01]
#   [ 7.16564651e+00  1.33793588e+01  2.98763610e+01]]
#
#  [[ 2.79693690e+00 -2.37726889e+00 -1.93081517e+00]
#   [ 2.27105895e+00 -1.14740477e+00 -1.64709039e+00]
#   [ 1.41007987e+00  1.09136483e-01 -8.81768417e-01]
#   ...
#   [ 7.05951872e+00  1.35367674e+01  2.78644035e+01]
#   [ 7.19297972e+00  1.30826563e+01  2.87966316e+01]
#   [ 7.29518118e+00  1.25600561e+01  2.97087029e+01]]
#
#  ...
#
#  [[-3.98327605e+00 -1.57477186e+01 -2.99777942e+01]
#   [-4.50915400e+00 -1.45178544e+01 -2.96940695e+01]
#   [-5.37013308e+00 -1.32613132e+01 -2.89287475e+01]
#   ...
#   [ 2.79305777e-01  1.66317704e-01 -1.82575543e-01]
#   [ 4.12766776e-01 -2.87793395e-01  7.49652546e-01]
#   [ 5.14968237e-01 -8.10393569e-01  1.66172377e+00]]
#
#  [[-4.12458298e+00 -1.52922374e+01 -3.08761704e+01]
#   [-4.65046094e+00 -1.40623732e+01 -3.05924456e+01]
#   [-5.51144002e+00 -1.28058320e+01 -2.98271236e+01]
#   ...
#   [ 1.37998840e-01  6.21798914e-01 -1.08095166e+00]
#   [ 2.71459839e-01  1.67687815e-01 -1.48723573e-01]
#   [ 3.73661301e-01 -3.54912359e-01  7.63347655e-01]]
#
#  [[-4.24130738e+00 -1.47783986e+01 -3.17438131e+01]
#   [-4.76718533e+00 -1.35485345e+01 -3.14600883e+01]
#   [-5.62816441e+00 -1.22919932e+01 -3.06947664e+01]
#   ...
#   [ 2.12744469e-02  1.13563767e+00 -1.94859442e+00]
#   [ 1.54735445e-01  6.81526576e-01 -1.01636633e+00]
#   [ 2.56936907e-01  1.58926402e-01 -1.04295101e-01]]]

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.set_title('Actual Training Lorenz Attractor using LSTM')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.plot(y_train[:,0],y_train[:,1],y_train[:,2])
plt.show()

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.set_title('Actual Lorenz Attractor for testing data')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.plot(y_test[:,0],y_test[:,1],y_test[:,2])
plt.show()

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.set_title('Predicted Lorenz Attractor using LSTM')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.plot(trainPredict[:,0],trainPredict[:,1],trainPredict[:,2])
plt.show()

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.set_title('Predicted Lorenz Attractor using LSTM')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.plot(testPredict[:,0],testPredict[:,1],testPredict[:,2])
plt.show()

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.set_title('Predicted Lorenz Attractor using RNN')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.plot(RNNtestPredict[:,0],testPredict[:,1],testPredict[:,2])
plt.show()

# %% [markdown]
# ## Testing with single starting point - predicting 1 ahead

# %%
SEQUENCE_SIZE = 10
single_t, single_lor = solve_lorenz(N=1) #try 10 random starting point initially, chnage to 100 later
single_x, single_y  = to_sequences_ray(SEQUENCE_SIZE,single_lor)
singlePredict = model.predict(single_x)
RNNsinglePredict = RNNmodel.predict(single_x)
print ("Shape of data: ", single_lor.shape)
print ("Shape of windowed data: ", single_x.shape)
# Out:
# Shape of data:  (1, 1000, 3)
# Shape of windowed data:  (1978, 10, 3)

# %%
print("Graphing LSTM true test output against predicted output ")
plt.figure(figsize=(20,20))
plt.subplot(3 ,1, 1)
plt.title("X ")
plt.plot(single_y[:,0:1], linewidth=3.0, linestyle=':', label='Actual X')
plt.plot(singlePredict[:,0:1], linestyle=':', label='Predicted X')
plt.legend(loc='upper right', shadow=True)

plt.subplot(3, 1, 2)
plt.title("Y ")
plt.plot(single_y[:,1:2], linewidth=3.0, linestyle=':', label='Actual Y')
plt.plot(singlePredict[:,1:2], linestyle=':', label='Predicted Y')
plt.legend(loc='upper right', shadow=True)

plt.subplot(3, 1, 3)
plt.title("Z ")
plt.plot(single_y[:,2:3], linewidth=3.0, linestyle=':', label='Predicted Z')
plt.plot(singlePredict[:,2:3], linestyle=':', label='Predicted Z')
plt.legend(loc='upper right', shadow=True)
plt.show()
# Out:
# Graphing LSTM true test output against predicted output

# %%
print("Graphing RNN true test output against predicted output ")
plt.figure(figsize=(20,20))
plt.subplot(3 ,1, 1)
plt.title("X ")
plt.plot(single_y[:,0:1], linewidth=3.0, linestyle=':', label='Actual X' )
plt.plot(RNNsinglePredict[:,0:1], linestyle=':', label='Predicted X')
plt.legend(loc='upper right', shadow=True)

plt.subplot(3, 1, 2)
plt.title("Y ")
plt.plot(single_y[:,1:2], linewidth=3.0, linestyle=':', label='Actual Y')
plt.plot(RNNsinglePredict[:,1:2], linestyle=':', label='Predicted Y')
plt.legend(loc='upper right', shadow=True)

plt.subplot(3, 1, 3)
plt.title("Z ")
plt.plot(single_y[:,2:3], linewidth=3.0, linestyle=':', label='Actual Z')
plt.plot(RNNsinglePredict[:,2:3], linestyle=':', label='Predicted Z')
plt.legend(loc='upper right', shadow=True)
plt.show()
# Out:
# Graphing RNN true test output against predicted output

# %%
print ("Calculating LSTM error with single time series")
print("Shape of output: ",single_y.shape)
err3D = single_y - singlePredict
err1D = (single_y - singlePredict)**2
err1D = err1D.sum(axis=-1)
err1D = np.sqrt(err1D)
aveErr = np.average(err1D)
print("Average error = ", aveErr)
# Out:
# Calculating LSTM error with single time series
# Shape of output:  (1978, 3)
# Average error =  0.27139130394181205

# %%
print ("Calculating RNN error with single time series")
print("Shape of output: ",single_y.shape)
RNNerr3D = single_y - RNNsinglePredict
RNNerr1D = (single_y - RNNsinglePredict)**2
RNNerr1D = RNNerr1D.sum(axis=-1)
RNNerr1D = np.sqrt(RNNerr1D)
RNNaveErr = np.average(RNNerr1D)
print("Average error = ", RNNaveErr)
# Out:
# Calculating RNN error with single time series
# Shape of output:  (1978, 3)
# Average error =  0.3653366152976761

# %%
print("Graphing true test output against predicted output ")
plt.figure(figsize=(20,10))
plt.title("Error value: LSTM vs RNN ")
plt.plot(err1D, linestyle='-', label='LSTM Error')
plt.plot(RNNerr1D, linestyle=':', label='RNN Error')
plt.legend(loc='upper right', shadow=True)
plt.show()
# Out:
# Graphing true test output against predicted output

# %% [markdown]
# ## Testing with single starting point - predicting 5 steps ahead

# %%
SEQUENCE_SIZE = 10
PREDICTION_LENGTH = 20
single_t, single_lor = solve_lorenz(N=1) #try 1 random starting point initially, chnage to 100 later
single_x, single_y  = to_sequences_ray(SEQUENCE_SIZE,single_lor)
pattern = single_x[1]
print ("Shape of  input data: ", single_x.shape)
print ("Shape of  pattern: ", pattern.shape)
pattern = pattern.reshape(1,SEQUENCE_SIZE,3)
prediction = pattern

print ("Shape of  input data: ", single_x.shape)
print ("Shape of  pattern: ", pattern.shape)
print ("Shape of  prediction data: ", prediction.shape)
next = model.predict(pattern)
print("next : ", next.shape)
nextNum = next[0]
print("next number: ", nextNum.shape)
nextNum = nextNum.reshape(1,1,3)
pattern = np.concatenate((pattern, nextNum), axis=1)
prediction = np.concatenate((prediction, nextNum), axis=1)
print ("Shape of  pattern: ", pattern.shape)
pattern = pattern[0:,1:len(pattern),0:]
print ("Shape of  pattern: ", pattern.shape)
print ("Shape of  prediction data: ", prediction.shape)
# Out:
# Shape of  input data:  (1978, 10, 3)
# Shape of  pattern:  (10, 3)
# Shape of  input data:  (1978, 10, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 10, 3)
# next :  (1, 3)
# next number:  (3,)
# Shape of  pattern:  (1, 11, 3)
# Shape of  pattern:  (1, 0, 3)
# Shape of  prediction data:  (1, 11, 3)

# %%
'''
pattern = pattern[1:len(pattern)]
pattern = pattern.reshape(1,SEQUENCE_SIZE,3)
print ("Shape of  pattern: ", pattern.shape)
print ("Shape of  prediction data: ", prediction.shape)
'''
# Out:
# '\npattern = pattern[1:len(pattern)]\npattern = pattern.reshape(1,SEQUENCE_SIZE,3)\nprint ("Shape of  pattern: ", pattern.shape)\nprint ("Shape of  prediction data: ", prediction.shape)\n'

# %%
# Improved version
SEQUENCE_SIZE = 10
PREDICTION_LENGTH = 2000
single_t, single_lor = solve_lorenz(N=1) #try 1 random starting point initially, chnage to 100 later
single_x, single_y  = to_sequences_ray(SEQUENCE_SIZE,single_lor)
pattern = single_x[1]
pattern = pattern.reshape(1,SEQUENCE_SIZE,3)
prediction = pattern
for i in range(PREDICTION_LENGTH):
    next = model.predict(pattern)
    #print("next : ", next.shape)
    nextNum = next[0]
    #print("next number: ", nextNum.shape)
    nextNum = nextNum.reshape(1,1,3)
    pattern = np.concatenate((pattern, nextNum), axis=1)
    prediction = np.concatenate((prediction, nextNum), axis=1)
    #print ("Shape of  pattern: ", pattern.shape)
    pattern = pattern[0:,1:SEQUENCE_SIZE+1,0:]
    print ("Shape of  pattern: ", pattern.shape)
    print ("Shape of  prediction data: ", prediction.shape)
# Out:
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 11, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 12, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 13, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 14, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 15, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 16, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 17, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 18, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 19, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 20, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 21, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 22, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 23, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 24, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 25, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 26, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 27, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 28, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 29, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 30, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 31, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 32, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 33, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 34, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 35, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 36, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 37, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 38, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 39, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 40, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 41, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 42, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 43, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 44, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 45, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 46, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 47, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 48, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 49, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 50, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 51, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 52, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 53, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 54, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 55, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 56, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 57, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 58, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 59, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 60, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 61, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 62, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 63, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 64, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 65, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 66, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 67, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 68, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 69, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 70, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 71, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 72, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 73, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 74, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 75, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 76, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 77, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 78, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 79, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 80, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 81, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 82, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 83, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 84, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 85, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 86, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 87, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 88, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 89, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 90, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 91, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 92, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 93, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 94, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 95, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 96, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 97, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 98, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 99, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 100, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 101, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 102, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 103, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 104, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 105, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 106, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 107, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 108, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 109, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 110, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 111, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 112, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 113, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 114, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 115, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 116, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 117, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 118, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 119, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 120, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 121, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 122, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 123, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 124, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 125, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 126, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 127, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 128, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 129, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 130, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 131, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 132, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 133, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 134, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 135, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 136, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 137, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 138, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 139, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 140, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 141, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 142, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 143, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 144, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 145, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 146, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 147, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 148, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 149, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 150, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 151, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 152, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 153, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 154, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 155, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 156, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 157, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 158, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 159, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 160, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 161, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 162, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 163, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 164, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 165, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 166, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 167, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 168, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 169, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 170, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 171, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 172, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 173, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 174, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 175, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 176, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 177, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 178, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 179, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 180, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 181, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 182, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 183, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 184, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 185, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 186, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 187, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 188, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 189, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 190, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 191, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 192, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 193, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 194, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 195, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 196, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 197, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 198, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 199, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 200, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 201, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 202, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 203, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 204, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 205, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 206, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 207, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 208, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 209, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 210, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 211, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 212, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 213, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 214, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 215, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 216, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 217, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 218, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 219, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 220, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 221, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 222, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 223, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 224, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 225, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 226, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 227, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 228, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 229, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 230, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 231, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 232, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 233, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 234, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 235, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 236, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 237, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 238, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 239, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 240, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 241, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 242, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 243, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 244, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 245, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 246, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 247, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 248, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 249, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 250, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 251, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 252, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 253, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 254, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 255, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 256, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 257, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 258, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 259, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 260, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 261, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 262, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 263, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 264, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 265, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 266, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 267, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 268, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 269, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 270, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 271, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 272, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 273, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 274, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 275, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 276, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 277, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 278, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 279, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 280, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 281, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 282, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 283, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 284, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 285, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 286, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 287, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 288, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 289, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 290, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 291, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 292, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 293, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 294, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 295, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 296, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 297, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 298, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 299, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 300, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 301, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 302, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 303, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 304, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 305, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 306, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 307, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 308, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 309, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 310, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 311, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 312, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 313, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 314, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 315, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 316, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 317, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 318, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 319, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 320, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 321, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 322, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 323, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 324, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 325, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 326, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 327, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 328, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 329, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 330, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 331, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 332, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 333, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 334, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 335, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 336, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 337, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 338, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 339, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 340, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 341, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 342, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 343, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 344, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 345, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 346, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 347, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 348, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 349, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 350, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 351, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 352, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 353, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 354, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 355, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 356, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 357, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 358, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 359, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 360, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 361, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 362, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 363, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 364, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 365, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 366, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 367, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 368, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 369, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 370, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 371, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 372, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 373, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 374, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 375, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 376, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 377, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 378, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 379, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 380, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 381, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 382, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 383, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 384, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 385, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 386, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 387, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 388, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 389, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 390, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 391, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 392, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 393, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 394, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 395, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 396, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 397, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 398, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 399, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 400, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 401, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 402, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 403, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 404, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 405, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 406, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 407, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 408, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 409, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 410, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 411, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 412, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 413, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 414, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 415, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 416, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 417, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 418, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 419, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 420, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 421, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 422, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 423, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 424, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 425, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 426, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 427, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 428, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 429, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 430, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 431, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 432, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 433, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 434, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 435, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 436, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 437, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 438, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 439, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 440, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 441, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 442, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 443, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 444, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 445, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 446, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 447, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 448, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 449, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 450, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 451, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 452, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 453, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 454, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 455, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 456, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 457, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 458, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 459, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 460, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 461, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 462, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 463, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 464, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 465, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 466, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 467, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 468, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 469, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 470, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 471, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 472, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 473, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 474, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 475, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 476, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 477, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 478, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 479, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 480, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 481, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 482, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 483, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 484, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 485, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 486, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 487, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 488, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 489, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 490, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 491, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 492, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 493, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 494, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 495, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 496, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 497, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 498, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 499, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 500, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 501, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 502, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 503, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 504, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 505, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 506, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 507, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 508, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 509, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 510, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 511, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 512, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 513, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 514, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 515, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 516, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 517, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 518, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 519, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 520, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 521, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 522, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 523, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 524, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 525, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 526, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 527, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 528, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 529, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 530, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 531, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 532, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 533, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 534, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 535, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 536, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 537, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 538, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 539, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 540, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 541, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 542, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 543, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 544, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 545, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 546, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 547, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 548, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 549, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 550, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 551, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 552, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 553, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 554, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 555, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 556, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 557, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 558, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 559, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 560, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 561, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 562, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 563, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 564, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 565, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 566, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 567, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 568, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 569, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 570, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 571, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 572, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 573, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 574, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 575, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 576, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 577, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 578, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 579, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 580, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 581, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 582, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 583, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 584, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 585, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 586, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 587, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 588, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 589, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 590, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 591, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 592, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 593, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 594, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 595, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 596, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 597, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 598, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 599, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 600, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 601, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 602, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 603, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 604, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 605, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 606, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 607, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 608, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 609, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 610, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 611, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 612, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 613, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 614, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 615, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 616, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 617, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 618, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 619, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 620, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 621, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 622, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 623, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 624, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 625, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 626, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 627, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 628, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 629, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 630, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 631, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 632, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 633, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 634, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 635, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 636, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 637, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 638, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 639, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 640, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 641, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 642, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 643, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 644, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 645, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 646, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 647, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 648, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 649, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 650, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 651, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 652, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 653, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 654, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 655, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 656, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 657, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 658, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 659, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 660, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 661, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 662, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 663, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 664, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 665, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 666, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 667, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 668, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 669, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 670, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 671, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 672, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 673, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 674, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 675, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 676, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 677, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 678, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 679, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 680, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 681, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 682, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 683, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 684, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 685, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 686, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 687, 3)
# ...
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1789, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1790, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1791, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1792, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1793, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1794, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1795, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1796, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1797, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1798, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1799, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1800, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1801, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1802, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1803, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1804, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1805, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1806, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1807, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1808, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1809, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1810, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1811, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1812, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1813, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1814, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1815, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1816, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1817, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1818, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1819, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1820, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1821, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1822, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1823, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1824, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1825, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1826, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1827, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1828, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1829, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1830, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1831, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1832, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1833, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1834, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1835, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1836, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1837, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1838, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1839, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1840, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1841, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1842, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1843, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1844, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1845, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1846, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1847, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1848, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1849, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1850, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1851, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1852, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1853, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1854, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1855, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1856, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1857, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1858, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1859, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1860, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1861, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1862, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1863, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1864, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1865, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1866, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1867, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1868, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1869, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1870, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1871, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1872, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1873, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1874, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1875, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1876, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1877, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1878, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1879, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1880, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1881, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1882, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1883, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1884, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1885, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1886, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1887, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1888, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1889, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1890, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1891, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1892, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1893, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1894, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1895, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1896, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1897, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1898, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1899, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1900, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1901, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1902, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1903, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1904, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1905, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1906, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1907, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1908, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1909, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1910, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1911, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1912, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1913, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1914, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1915, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1916, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1917, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1918, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1919, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1920, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1921, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1922, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1923, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1924, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1925, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1926, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1927, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1928, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1929, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1930, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1931, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1932, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1933, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1934, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1935, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1936, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1937, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1938, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1939, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1940, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1941, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1942, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1943, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1944, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1945, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1946, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1947, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1948, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1949, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1950, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1951, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1952, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1953, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1954, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1955, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1956, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1957, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1958, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1959, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1960, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1961, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1962, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1963, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1964, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1965, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1966, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1967, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1968, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1969, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1970, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1971, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1972, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1973, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1974, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1975, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1976, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1977, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1978, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1979, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1980, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1981, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1982, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1983, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1984, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1985, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1986, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1987, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1988, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1989, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1990, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1991, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1992, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1993, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1994, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1995, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1996, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1997, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1998, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 1999, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 2000, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 2001, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 2002, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 2003, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 2004, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 2005, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 2006, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 2007, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 2008, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 2009, 3)
# Shape of  pattern:  (1, 10, 3)
# Shape of  prediction data:  (1, 2010, 3)

# %%
print ("Shape of  actual: ", single_y.shape)
prediction = prediction.reshape(SEQUENCE_SIZE+PREDICTION_LENGTH,3)
print ("Shape of  prediction: ", prediction.shape)
# Out:
# Shape of  actual:  (1978, 3)
# Shape of  prediction:  (2010, 3)

# %%
print("Graphing RNN true test output against predicted output ")
plt.figure(figsize=(20,20))
plt.subplot(3 ,1, 1)
plt.title("X ")
plt.plot(single_y[:,0:1], linewidth=3.0, linestyle=':', label='Actual X' )
plt.plot(prediction[:,0:1], linestyle=':', label='Predicted X')
plt.legend(loc='upper right', shadow=True)
# Out:
# Graphing RNN true test output against predicted output

# %%
print("Graphing RNN true test output against predicted output ")
plt.figure(figsize=(20,20))
plt.subplot(3 ,1, 1)
plt.title("X ")
plt.plot(single_y[:,0:1], linewidth=3.0, linestyle=':', label='Actual X' )
plt.plot(prediction[1,:,0:1], linestyle=':', label='Predicted X')
plt.legend(loc='upper right', shadow=True)

plt.subplot(3, 1, 2)
plt.title("Y ")
plt.plot(single_y[:,1:2], linewidth=3.0, linestyle=':', label='Actual Y')
plt.plot(prediction[1,:,1:2], linestyle=':', label='Predicted Y')
plt.legend(loc='upper right', shadow=True)

plt.subplot(3, 1, 3)
plt.title("Z ")
plt.plot(single_y[:,2:3], linewidth=3.0, linestyle=':', label='Actual Z')
plt.plot(prediction[1,:,2:3], linestyle=':', label='Predicted Z')
plt.legend(loc='upper right', shadow=True)
plt.show()
# Out:
# Graphing RNN true test output against predicted output
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-60-4da0b6f4a64b> in <module>()
#       4 plt.title("X ")
#       5 plt.plot(single_y[:,0:1], linewidth=3.0, linestyle=':', label='Actual X' )
# ----> 6 plt.plot(prediction[1,:,0:1], linestyle=':', label='Predicted X')
#       7 plt.legend(loc='upper right', shadow=True)
#       8
#
# IndexError: too many indices for array

# %%
print ("Calculating LSTM error with single time series")
print("Shape of output: ",single_y.shape)
err3D = single_y - prediction
err1D = (single_y - prediction)**2
err1D = err1D.sum(axis=-1)
err1D = np.sqrt(err1D)
aveErr = np.average(err1D)
print("Average error = ", aveErr)
# Out:
# Calculating LSTM error with single time series
# Shape of output:  (1978, 3)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-45400b182285> in <module>()
#       1 print ("Calculating LSTM error with single time series")
#       2 print("Shape of output: ",single_y.shape)
# ----> 3 err3D = single_y - prediction
#       4 err1D = (single_y - prediction)**2
#       5 err1D = err1D.sum(axis=-1)
#
# ValueError: operands could not be broadcast together with shapes (1978,3) (2010,3)

# %%
print ("Calculating RNN error with single time series")
print("Shape of output: ",single_y.shape)
RNNerr3D = single_y - RNNsinglePredict
RNNerr1D = (single_y - RNNsinglePredict)**2
RNNerr1D = RNNerr1D.sum(axis=-1)
RNNerr1D = np.sqrt(RNNerr1D)
RNNaveErr = np.average(RNNerr1D)
print("Average error = ", RNNaveErr)
# Out:
# Calculating RNN error with single time series
# Shape of output:  (1978, 3)
# Average error =  0.3653366152976761

# %%
print("Graphing true test output against predicted output ")
plt.figure(figsize=(20,10))
plt.title("Error value: LSTM vs RNN ")
plt.plot(err1D, linestyle='-', label='LSTM Error')
plt.plot(RNNerr1D, linestyle=':', label='RNN Error')
plt.legend(loc='upper right', shadow=True)
plt.show()
# Out:
# Graphing true test output against predicted output

# %% [markdown]
# References:
# 1. http://ipywidgets.readthedocs.io/en/latest/examples/Lorenz%20Differential%20Equations.html
# 2. https://github.com/mspieg/dynamical-systems/blob/master/LorenzEquations.ipynb
# 3. https://en.wikipedia.org/wiki/List_of_dynamical_systems_and_differential_equations_topics
# 4. http://ipython-books.github.io/chapter-12-deterministic-dynamical-systems/
# http://ipython-books.github.io/
# 5. http://adventuresinmachinelearning.com/recurrent-neural-networks-lstm-tutorial-tensorflow/
# 6. http://iamtrask.github.io/2015/11/15/anyone-can-code-lstm/
# 7. http://colah.github.io/posts/2015-08-Understanding-LSTMs/
# 8. http://www.iro.umontreal.ca/~lisa/pointeurs/RazvanPascanuThesis.pdf (also in downloads)
# 9. https://www.gribblelab.org/compneuro/2_Modelling_Dynamical_Systems.html#orgheadline5
# 10. https://blog.statsbot.co/time-series-prediction-using-recurrent-neural-networks-lstms-807fa6ca7f
# 11. https://github.com/yuqirose/trnn poster - http://roseyu.com/Materials/nips17-tsw-poster.pdf
# 12. https://machinelearningmastery.com/prepare-univariate-time-series-data-long-short-term-memory-networks/
